# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import re
import datetime
from sklearn.model_selection import train_test_split
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers

# %%
deals_df = pd.read_csv('PE_Dataset.csv')
deals_df.head()
# Out:
#                          Name  Unnamed: 1  Fiscal Year  \
# 0                        Kroo         NaN          NaN
# 1  Swoop (Financial Software)         NaN          NaN
# 2               Fiat Republic         NaN          NaN
# 3                       Backd         NaN          NaN
# 4                         Bud         NaN          NaN
#
#                                      Pitchbook Link  \
# 0  https://pitchbook.com/profiles/company/221945-05
# 1  https://pitchbook.com/profiles/company/231457-06
# 2  https://pitchbook.com/profiles/company/484063-30
# 3  https://pitchbook.com/profiles/company/498267-82
# 4  https://pitchbook.com/profiles/company/169783-84
#
#                  Company Name  Year Founded  \
# 0                        Kroo        2016.0
# 1  Swoop (Financial Software)        2018.0
# 2               Fiat Republic        2021.0
# 3                       Backd           NaN
# 4                         Bud        2015.0
#
#                                     Employee Growth  Current Employees  \
# 0                                 2021: 50, 2020: 47                80
# 1                                 2021: 68, 2020: 58                80
# 2                                            84.2125                25
# 3                                                NaN               NaN
# 4  2021: 166, 2020: 76, 2019: 70, 2018: 50, 2017: 23               167
#
#                                             Keywords  \
# 0  cash  payment software, e-money account, finan...
# 1  business financing, business funding, business...
# 2  banking  api tool, crypto platform, crypto sof...
# 3  crypto exchange, defi system, defi wallets, li...
# 4  financial  software, open banking, open bankin...
#
#                                   Verticals  \
# 0          FinTech, Mobile, Mobile Commerce
# 1                FinTech, Mobile, SaaS, TMT
# 2  Cryptocurrency/Blockchain, FinTech, SaaS
# 3        Cryptocurrency/Blockchain, FinTech
# 4                           FinTech, Mobile
#
#                                       All Industries  \
# 0  Application Software, Financial Software*, Oth...
# 1           Financial Software*, Specialized Finance
# 2      Financial Software*, Other Financial Services
# 3      Financial Software*, Other Financial Services
# 4  Application Software, Financial Software*, Oth...
#
#                              Lead/Sole Investors  # Follow-on Investors  \
# 0                                            NaN                    NaN
# 1                                            NaN                    2.0
# 2                                 Credo Ventures                    1.0
# 3  Advanced Blockchain (DUS: BWQ) (Simon Telian)                    NaN
# 4                     TDR Capital (Gary Lindsay)                    1.0
#
#          Financing Status     Business Status   Deal Date  \
# 0  Venture Capital-Backed  Generating Revenue  31/12/2023
# 1  Venture Capital-Backed  Generating Revenue  13/06/2022
# 2  Venture Capital-Backed  Generating Revenue  08/06/2022
# 3  Venture Capital-Backed             Startup  07/06/2022
# 4  Venture Capital-Backed  Generating Revenue  07/06/2022
#
#   Total Invested Equity Raised to Date       Deal Class       Deal Type  \
# 0                   NaN            NaN  Venture Capital  Later Stage VC
# 1                  6.74           8.78  Venture Capital  Later Stage VC
# 2                     6              6  Venture Capital      Seed Round
# 3                   3.5            3.5  Venture Capital  Early Stage VC
# 4                    80         112.88  Venture Capital  Later Stage VC
#
#   VC Round Deal Type 2 Deal Size    Series  Deal No. VC Round Up/Down/Flat  \
# 0        6    Series C       NaN  Series C         6                   NaN
# 1        4    Series A      6.74  Series A         8                   NaN
# 2        1  Seed Round         6       NaN         2                   NaN
# 3        1    Series A       3.5  Series A         1                   NaN
# 4        6    Series B        80  Series B         8                   NaN
#
#   Current Financing Status                              Financing Status Note  \
# 0   Venture Capital-Backed  The  company is reportedly seeking Series C ve...
# 1   Venture Capital-Backed  The  company raised GBP 5.4 million of Series ...
# 2   Venture Capital-Backed  The  company raised $6 million of seed funding...
# 3   Venture Capital-Backed  The  company raised $3.5 million of Series A v...
# 4   Venture Capital-Backed  The  company raised $80 million of Series B ve...
#
#   Current Business Status                                        Description  \
# 0      Generating Revenue  Developer  of a payment mobile application des...
# 1      Generating Revenue  Developer  of one-stop money shop application ...
# 2      Generating Revenue  Developer  of crypto-focused, e-money-regulate...
# 3                 Startup  Developer  of a crypto-based consumer lending ...
# 4      Generating Revenue  Developer  of an open banking application desi...
#
#                                            Investors  \
# 0                                                NaN
# 1  Arab Bank (AMM: ARBK), Enterprise Ireland, IAG...
# 2  Breega, Connect Ventures, Credo Ventures, Emer...
# 3  Advanced Blockchain (DUS: BWQ) (Simon Telian),...
# 4  Outward Venture Capital, SEI Investments (NAS:...
#
#                                        Deal Synopsis  Deal Date.1
# 0  The  company raised GBP 184,000 of seed fundin...          NaN
# 1  The  company raised GBP 97,848 of angel fundin...          NaN
# 2  The  company raised GBP 79,410 of angel fundin...          NaN
# 3  The  company raised GBP 5.56 million of equity...          NaN
# 4  The  company raised GBP 77,057 of angel fundin...          NaN

# %% [markdown]
# ## 1. Data Preprocessing

# %% [markdown]
# ### 1.1 Define functions required for Data Preprocessing and Cleaning

# %%
# Assign single (mean) value for employee growth across years
def update_emp_growth(df):
    mean_emp_growth = []
    for idx, value in enumerate(df["Employee Growth"]):
        if type(value) is str:
            value = value.split(',')
            if value[0].find(":") != -1:
                value = [float(val[val.find(':') + 2:]) for val in value]
            else:
                value[0] = float(value[0])
            mean_emp_growth.append(round(sum(value)/len(value)))
        else:
            mean_emp_growth.append(value)
    return mean_emp_growth

# Change data type from str to float excluding nan values
def change_type(df, column):
    new_val = []
    for idx, val in enumerate(df[column]):
        if type(val) is str:
            val = val.replace(',', '')
            val = float(val)
        new_val.append(val)   
    return new_val

# %%
# If deal date is not specified, get deal date from synopsis
def update_deal_date(df):
    new_date = []
    months = {"jan" :1, "january":1, "feb":2, "february":2, "mar":3, "march":3, "apr":4, "april":4, "may":5, "jun":6, "june":6, 
            "jul":7, "july":7, "aug":8, "august":8, "sept":9, "september":9, "oct":10, "october":10, 
            "nov":11, "november":11, "dec":12, "december":12}
    for idx, val in enumerate(df["Deal Date"]):
        if type(val) is not pd._libs.tslibs.timestamps.Timestamp:
            synopsis = df.iloc[idx]["Deal Synopsis"].split()
            day = []
            if len(list(filter(lambda a: (a.lower() in  months.keys()), synopsis))) == 0:
                new_date.append(val)
                continue
            day = 1
            month = ""
            year = df.iloc[idx]["Fiscal Year"] if not pd.isnull(df.iloc[idx]["Fiscal Year"]) else 2022
            for index, word in enumerate(synopsis):
                word=word.replace(",", "")
                if word.lower() in months.keys():
                    month = word
                    year_candidates = synopsis[max(0, index-2): index+3]
                    for word in year_candidates:
                        word = word.replace(",", "")
                        word = word.replace(".", "")
                        if len(word) > 4:
                            continue
                        try:
                            int_word = int(word)
                            if int_word > 31 or int_word < 1:
                                if len(word) == 2:
                                    year = int("20"+word)
                                elif len(word) == 4:
                                    year = int(word)
                                else:
                                    pass
                                continue
                            else:
                                day = int_word 
                        except ValueError:
                            continue
            new_date.append(datetime.date(year, months[month.lower()], day))
        else:
            new_date.append(val)
    return new_date

# %% [markdown]
# ### 1.2 Data Preprocesing and Cleaning

# %%
def preprocess(df):
    df = df.copy()
    # Drop irrelevant, duplicate, high cardinality, single value columns 
    df = df.drop(['Unnamed: 1', "Pitchbook Link", "Deal Date.1", "Year Founded", 'Financing Status', 'Company Name', 'Investors', 'Series'], axis = 1)
    df.loc[pd.isnull(df['Deal Synopsis']), 'Deal Synopsis'] = "Unavailable"
    df["Deal Date"] = pd.to_datetime(df["Deal Date"], errors='coerce', infer_datetime_format=True)
    df["Deal Date"] = update_deal_date(df)
    df.rename(columns={'Employee Growth ': 'Employee Growth'}, inplace=True)

    df = df.loc[~df['Deal Type'].isin(['Product Crowdfunding', 'Equity Crowdfunding'])]

    df.loc[pd.isnull(df['Deal Date']), 'Deal Date'] = df.mode()['Deal Date'][0]  # For deal dates that are undisclosed in the synopsis
    #df.loc[pd.isnull(df['Year Founded']), 'Year Founded'] = df.mode()['Deal Date'][0]
    df.loc[pd.isnull(df['Fiscal Year']), 'Fiscal Year'] = df['Deal Date'].dt.year
    df['Deal Date']  = df["Deal Date"].dt.date

    df['Employee Growth'] = update_emp_growth(df)
    df.loc[pd.isnull(df['Employee Growth']), 'Employee Growth']  = round(df[~df['Employee Growth'].isnull()]['Employee Growth'].mean(), 2)
    df['Current Employees'] = change_type(df, "Current Employees")
    df.loc[pd.isnull(df['Current Employees']), 'Current Employees'] = round(df[~df['Current Employees'].isnull()]['Current Employees'].mean(), 0)
    df['Total Invested Equity'] = change_type(df, "Total Invested Equity")
    df.loc[pd.isnull(df['Total Invested Equity']), 'Total Invested Equity'] = round(df[~df['Total Invested Equity'].isnull()]['Total Invested Equity'].mean(), 2)
    df['Deal Size'] = change_type(df, 'Deal Size')
    df.loc[pd.isnull(df['Deal Size']), 'Deal Size'] = round(df[~df['Deal Size'].isnull()]['Deal Size'].mean(), 2)
    df['Raised to Date'] = change_type(df, 'Raised to Date')
    df.loc[pd.isnull(df['Raised to Date']), 'Raised to Date'] = round(df[~df['Raised to Date'].isnull()]['Total Invested Equity'].mean(), 2)

    df.loc[pd.isnull(df['# Follow-on Investors']), '# Follow-on Investors'] = 0
    df.loc[pd.isnull(df['VC Round Up/Down/Flat']), 'VC Round Up/Down/Flat'] = 0
    df.loc[pd.isnull(df['VC Round']), 'VC Round'] = -1
    df.loc[pd.isnull(df['Lead/Sole Investors']), 'Lead/Sole Investors'] = "None"
    df.loc[pd.isnull(df['Deal Type 2']), 'Deal Type 2'] = "NA"

    df["VC Round Up/Down/Flat"] = df["VC Round Up/Down/Flat"].replace({"Up Round": 1, "Down Round": -1, "Flat Round": 2})
    df["VC Round"] = df["VC Round"].replace({"Angel": 0})
    df["VC Round"] = df["VC Round"].astype(int)

    return df

# %%
clean_df = preprocess(deals_df)

# %%
clean_df.head()
# Out:
#                          Name  Fiscal Year  Employee Growth  \
# 0                        Kroo       2023.0            48.00
# 1  Swoop (Financial Software)       2022.0            63.00
# 2               Fiat Republic       2022.0            84.00
# 3                       Backd       2022.0            78.29
# 4                         Bud       2022.0            77.00
#
#    Current Employees                                           Keywords  \
# 0               80.0  cash  payment software, e-money account, finan...
# 1               80.0  business financing, business funding, business...
# 2               25.0  banking  api tool, crypto platform, crypto sof...
# 3              127.0  crypto exchange, defi system, defi wallets, li...
# 4              167.0  financial  software, open banking, open bankin...
#
#                                   Verticals  \
# 0          FinTech, Mobile, Mobile Commerce
# 1                FinTech, Mobile, SaaS, TMT
# 2  Cryptocurrency/Blockchain, FinTech, SaaS
# 3        Cryptocurrency/Blockchain, FinTech
# 4                           FinTech, Mobile
#
#                                       All Industries  \
# 0  Application Software, Financial Software*, Oth...
# 1           Financial Software*, Specialized Finance
# 2      Financial Software*, Other Financial Services
# 3      Financial Software*, Other Financial Services
# 4  Application Software, Financial Software*, Oth...
#
#                              Lead/Sole Investors  # Follow-on Investors  \
# 0                                           None                    0.0
# 1                                           None                    2.0
# 2                                 Credo Ventures                    1.0
# 3  Advanced Blockchain (DUS: BWQ) (Simon Telian)                    0.0
# 4                     TDR Capital (Gary Lindsay)                    1.0
#
#       Business Status   Deal Date  Total Invested Equity  Raised to Date  \
# 0  Generating Revenue  2023-12-31                  13.68           13.68
# 1  Generating Revenue  2022-06-13                   6.74            8.78
# 2  Generating Revenue  2022-06-08                   6.00            6.00
# 3             Startup  2022-06-07                   3.50            3.50
# 4  Generating Revenue  2022-06-07                  80.00          112.88
#
#         Deal Class       Deal Type  VC Round Deal Type 2  Deal Size  Deal No.  \
# 0  Venture Capital  Later Stage VC         6    Series C      15.34         6
# 1  Venture Capital  Later Stage VC         4    Series A       6.74         8
# 2  Venture Capital      Seed Round         1  Seed Round       6.00         2
# 3  Venture Capital  Early Stage VC         1    Series A       3.50         1
# 4  Venture Capital  Later Stage VC         6    Series B      80.00         8
#
#    VC Round Up/Down/Flat Current Financing Status  \
# 0                      0   Venture Capital-Backed
# 1                      0   Venture Capital-Backed
# 2                      0   Venture Capital-Backed
# 3                      0   Venture Capital-Backed
# 4                      0   Venture Capital-Backed
#
#                                Financing Status Note Current Business Status  \
# 0  The  company is reportedly seeking Series C ve...      Generating Revenue
# 1  The  company raised GBP 5.4 million of Series ...      Generating Revenue
# 2  The  company raised $6 million of seed funding...      Generating Revenue
# 3  The  company raised $3.5 million of Series A v...                 Startup
# 4  The  company raised $80 million of Series B ve...      Generating Revenue
#
#                                          Description  \
# 0  Developer  of a payment mobile application des...
# 1  Developer  of one-stop money shop application ...
# 2  Developer  of crypto-focused, e-money-regulate...
# 3  Developer  of a crypto-based consumer lending ...
# 4  Developer  of an open banking application desi...
#
#                                        Deal Synopsis
# 0  The  company raised GBP 184,000 of seed fundin...
# 1  The  company raised GBP 97,848 of angel fundin...
# 2  The  company raised GBP 79,410 of angel fundin...
# 3  The  company raised GBP 5.56 million of equity...
# 4  The  company raised GBP 77,057 of angel fundin...

# %%
clean_df.info()  # No null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2440 entries, 0 to 2546
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      2440 non-null   object
#  1   Fiscal Year               2440 non-null   float64
#  2   Employee Growth           2440 non-null   float64
#  3   Current Employees         2440 non-null   float64
#  4   Keywords                  2440 non-null   object
#  5   Verticals                 2440 non-null   object
#  6   All Industries            2440 non-null   object
#  7   Lead/Sole Investors       2440 non-null   object
#  8   # Follow-on Investors     2440 non-null   float64
#  9   Business Status           2440 non-null   object
#  10  Deal Date                 2440 non-null   object
#  11  Total Invested Equity     2440 non-null   float64
#  12  Raised to Date            2440 non-null   float64
#  13  Deal Class                2440 non-null   object
#  14  Deal Type                 2440 non-null   object
#  15  VC Round                  2440 non-null   int32
#  16  Deal Type 2               2440 non-null   object
#  17  Deal Size                 2440 non-null   float64
#  18  Deal No.                  2440 non-null   int64
#  19  VC Round Up/Down/Flat     2440 non-null   int64
#  20  Current Financing Status  2440 non-null   object
#  21  Financing Status Note     2440 non-null   object
#  22  Current Business Status   2440 non-null   object
#  23  Description               2440 non-null   object
#  24  Deal Synopsis             2440 non-null   object
# dtypes: float64(7), int32(1), int64(2), object(15)
# memory usage: 550.6+ KB

# %% [markdown]
# ### 1.3 Flatten Data by Company (To be used for generating time series and text embeddings)

# %%
clean_df = clean_df.sort_values(by=['Name', 'Fiscal Year'], ascending=False)

# %%
company = {}
for name in clean_df['Name']:
    if name in company.keys():
        company[name] += 1
    else:
        company[name] = 1

# %%
emp_growth, comp_name, curr_emp, keywords, verticals, industries = [], [], [], [], [], []
bstatus, fstatus, curr_bstatus, FSNote, desc, raised, last_deal_no = [], [], [], [], [], [], []
lead_investor, fo_investor = [], []
dd_t3, dd_t2, dd_t1, dd_next, target, synopsis_t3, synopsis_t2, synopsis_t1 = [], [], [], [], [], [], [], []
prev_equity, avg_equity = [], []
class_t1, class_t2, class_t3 = [], [], []
type_t1, type_t2, type_t3 = [], [], []
type2_t1, type2_t2, type2_t3 = [], [], []
vcround_avg, size_avg, prev_vc = [], [], []

for name, num_deals in company.items():
    df = clean_df[clean_df.Name == name]
    df = df.reset_index(drop=True)
    comp_name.append(name)
    emp_growth.append(df['Employee Growth'][0])
    curr_emp.append(df['Current Employees'][0])
    keywords.append(df['Keywords'][0])
    verticals.append(df['Verticals'][0])
    industries.append(df['All Industries'][0])
    bstatus.append(df['Business Status'][0])
    fstatus.append(df['Current Financing Status'][0])
    desc.append(df['Description'][0])
    FSNote.append(df['Financing Status Note'][0])
    raised.append(df['Raised to Date'][0])
    curr_bstatus.append(['Current Bussiness Status'][0])
    dd_next.append(df['Deal Date'].iloc[0])
    if df['Deal Date'].iloc[0].year == 2022 and num_deals > 1:
        target.append(1)
        df = df.iloc[1:]
        df = df.reset_index(drop=True)
    else:
        target.append(0)  
        
    last_deal_no.append(df['Deal No.'][0])
    lead_investor.append(', '.join([investor for investor in df['Lead/Sole Investors']]))
    fo_investor.append(df['# Follow-on Investors'].mean())
    vcround_avg.append(round(df['VC Round'].mean(), 2))
    size_avg.append(round(df['Deal Size'].mean(), 2))
    avg_equity.append(round(df['Total Invested Equity'].mean(), 2))
    if num_deals == 1:
        prev_vc.append(0)
        prev_equity.append(0)
        class_t2.append("None") 
        class_t3.append("None") 
        type_t2.append("None") 
        type_t3.append("None") 
        type2_t2.append("None")
        type2_t3.append("None") 
        synopsis_t2.append("None")
        synopsis_t3.append("None")
        dd_t2.append("None")
        dd_t3.append("None")
    else:
        prev_vc.append(df["VC Round Up/Down/Flat"][0])
        prev_equity.append(df["Total Invested Equity"][0])
    if num_deals == 2 or (num_deals == 3 and df.shape[0] == 2):
        class_t3.append("None")
        type_t3.append("None")
        type2_t3.append("None")
        synopsis_t3.append("None")
        dd_t3.append("None")
        if df.shape[0] == 1:
            class_t2.append("None")
            type_t2.append("None")
            type2_t2.append("None")
            synopsis_t2.append("None")
            dd_t2.append("None")
    
    for idx, row in df.iterrows():
        if idx > 2:
            break
        elif idx == 0:
            class_t1.append(row["Deal Class"])
            type_t1.append(row["Deal Type"])
            type2_t1.append(row["Deal Type 2"])
            synopsis_t1.append(row["Deal Synopsis"])
            dd_t1.append(row["DateVector"])
        elif idx == 1:
            class_t2.append(row["Deal Class"])
            type_t2.append(row["Deal Type"])
            type2_t2.append(row["Deal Type 2"])
            synopsis_t2.append(row["Deal Synopsis"])
            dd_t2.append(row["DateVector"])
        else:
            class_t3.append(row["Deal Class"])
            type_t3.append(row["Deal Type"])
            type2_t3.append(row["Deal Type 2"])
            synopsis_t3.append(row["Deal Synopsis"])
            dd_t3.append(row["DateVector"])

# %%
flat_dict = {"Company": comp_name, "EmployeeGrowth": emp_growth, "CurrentEmployees": curr_emp,
             "Keywords": keywords, "Verticals": verticals, "Industries": industries, 
             "BusinessStatus": bstatus, "CurrentBusinessStatus": curr_bstatus, "CurrentFinancingStatus": fstatus,
             "TotalRaised": raised, "LastDealNo": last_deal_no, "PrevVC(Up/Down)": prev_vc, "AvgDealSize": size_avg,
             "AvgEquity": avg_equity, "PrevEquity": prev_equity,
             "AvgVCRound": vcround_avg, "LeadInvestor": lead_investor, "NumFollowOnInvestors": fo_investor,
             "DealDate_t3": dd_t3, "Class_t3": class_t3, "Type_t3": type_t3, "Type2_t3": type2_t3, "Synopsis_t3": synopsis_t3,
             "DealDate_t2": dd_t2, "Class_t2": class_t2, "Type_t2": type_t2, "Type2_t2": type2_t2, "Synopsis_t2": synopsis_t2,
             "DealDate_t1": dd_t1, "Class_t1": class_t1, "Type_t1": type_t1, "Type2_t1": type2_t1, "Synopsis_t1": synopsis_t1,
             "Description": desc, "FinStatusNote": FSNote, "NextDealDate": dd_next, "isDeal": target}

# %%
flat_df = pd.DataFrame(flat_dict)
flat_df.head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Company</th>
#       <th>EmployeeGrowth</th>
#       <th>CurrentEmployees</th>
#       <th>Keywords</th>
#       <th>Verticals</th>
#       <th>Industries</th>
#       <th>BusinessStatus</th>
#       <th>CurrentBusinessStatus</th>
#       <th>CurrentFinancingStatus</th>
#       <th>TotalRaised</th>
#       <th>LastDealNo</th>
#       <th>PrevVC(Up/Down)</th>
#       <th>AvgDealSize</th>
#       <th>AvgEquity</th>
#       <th>PrevEquity</th>
#       <th>AvgVCRound</th>
#       <th>LeadInvestor</th>
#       <th>NumFollowOnInvestors</th>
#       <th>DealDate_t3</th>
#       <th>Class_t3</th>
#       <th>Type_t3</th>
#       <th>Type2_t3</th>
#       <th>Synopsis_t3</th>
#       <th>DealDate_t2</th>
#       <th>Class_t2</th>
#       <th>Type_t2</th>
#       <th>Type2_t2</th>
#       <th>Synopsis_t2</th>
#       <th>DealDate_t1</th>
#       <th>Class_t1</th>
#       <th>Type_t1</th>
#       <th>Type2_t1</th>
#       <th>Synopsis_t1</th>
#       <th>Description</th>
#       <th>FinStatusNote</th>
#       <th>NextDealDate</th>
#       <th>isDeal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>vabble (Financial Software)</td>
#       <td>78.29</td>
#       <td>3.0</td>
#       <td>financial platform, funding options, instituti...</td>
#       <td>FinTech</td>
#       <td>Financial Software*, Other Capital Markets/Ins...</td>
#       <td>Generating Revenue</td>
#       <td>Current Bussiness Status</td>
#       <td>Venture Capital-Backed</td>
#       <td>13.68</td>
#       <td>1</td>
#       <td>0</td>
#       <td>15.34</td>
#       <td>13.68</td>
#       <td>0.00</td>
#       <td>1.00</td>
#       <td>Fuel Ventures</td>
#       <td>0.000000</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>[0.0, 0.0, 0.0, 0.09221074, 0.011161167, 0.002...</td>
#       <td>Venture Capital</td>
#       <td>Seed Round</td>
#       <td>Seed Round</td>
#       <td>The  company raised GBP 947,791 of venture fun...</td>
#       <td>Developer  of a financial platform intended to...</td>
#       <td>The company raised seed funding from Fuel Vent...</td>
#       <td>2021-01-01</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>trustshare</td>
#       <td>84.00</td>
#       <td>16.0</td>
#       <td>financial  services, financial services app, f...</td>
#       <td>B2B Payments, FinTech, SaaS</td>
#       <td>Business/Productivity Software, Financial Soft...</td>
#       <td>Generating Revenue</td>
#       <td>Current Bussiness Status</td>
#       <td>Venture Capital-Backed</td>
#       <td>4.16</td>
#       <td>2</td>
#       <td>1</td>
#       <td>3.20</td>
#       <td>3.20</td>
#       <td>3.20</td>
#       <td>1.00</td>
#       <td>Nauta Capital (Carles Roqueta)</td>
#       <td>0.000000</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>[0.0, 0.038540773, 0.09711099, 0.22219688, 0.0...</td>
#       <td>Venture Capital</td>
#       <td>Seed Round</td>
#       <td>Seed Round</td>
#       <td>The company raised venture funding from Loyal ...</td>
#       <td>Developer  of an online platform intended for ...</td>
#       <td>The  company raised an undisclosed amount of v...</td>
#       <td>2022-01-04</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>swIDch</td>
#       <td>9.00</td>
#       <td>9.0</td>
#       <td>authentication  technology, digital payment ca...</td>
#       <td>FinTech, SaaS</td>
#       <td>Business/Productivity Software, Network Manage...</td>
#       <td>Generating Revenue</td>
#       <td>Current Bussiness Status</td>
#       <td>Venture Capital-Backed</td>
#       <td>13.68</td>
#       <td>2</td>
#       <td>0</td>
#       <td>15.34</td>
#       <td>13.68</td>
#       <td>0.00</td>
#       <td>1.00</td>
#       <td>BKT Capital</td>
#       <td>0.000000</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>[0.13642836, 0.100364886, 0.0, 0.04559175, 0.0...</td>
#       <td>Venture Capital</td>
#       <td>Early Stage VC</td>
#       <td>NA</td>
#       <td>The  company raised EUR 7.5 million of Series ...</td>
#       <td>Developer  of authentication technology intend...</td>
#       <td>The company raised venture funding from BKT Ca...</td>
#       <td>2021-01-01</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>sqft.capital</td>
#       <td>78.29</td>
#       <td>11.0</td>
#       <td>data  insights marketplace, development financ...</td>
#       <td>FinTech</td>
#       <td>Application Software, Business/Productivity So...</td>
#       <td>Generating Revenue</td>
#       <td>Current Bussiness Status</td>
#       <td>Venture Capital-Backed</td>
#       <td>0.93</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0.76</td>
#       <td>0.76</td>
#       <td>0.00</td>
#       <td>1.00</td>
#       <td>RO Capital Partners (Edward Rowlandson)</td>
#       <td>1.000000</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>[0.0, 0.5521339, 0.0, 0.0, 0.089344405, 0.0, 0...</td>
#       <td>Venture Capital</td>
#       <td>Later Stage VC</td>
#       <td>NA</td>
#       <td>The  company raised GBP 8.39 million of ventur...</td>
#       <td>Developer  of a funding and data insights mark...</td>
#       <td>The  company raised GBP 600,000 of venture fun...</td>
#       <td>2022-10-05</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>so-sure</td>
#       <td>12.00</td>
#       <td>21.0</td>
#       <td>contents insurance, insurance application, ins...</td>
#       <td>FinTech, InsurTech, Mobile, SaaS, TMT</td>
#       <td>Financial Software, Multi-line Insurance*</td>
#       <td>Generating Revenue</td>
#       <td>Current Bussiness Status</td>
#       <td>Venture Capital-Backed</td>
#       <td>4.53</td>
#       <td>4</td>
#       <td>1</td>
#       <td>8.80</td>
#       <td>7.97</td>
#       <td>3.70</td>
#       <td>-0.25</td>
#       <td>Breega (Benoit Marrel), AFL Incubator (George ...</td>
#       <td>0.000000</td>
#       <td>[0.0, 0.24082406, 0.0, 0.0, 0.027381714, 0.044...</td>
#       <td>Other</td>
#       <td>Accelerator/Incubator</td>
#       <td>NA</td>
#       <td>The  company raised GBP 949,701 of venture fun...</td>
#       <td>[0.08290465, 0.0404652, 0.0, 0.05820749, 0.076...</td>
#       <td>Other</td>
#       <td>Accelerator/Incubator</td>
#       <td>NA</td>
#       <td>The company raised GBP 350,000 of seed funding...</td>
#       <td>[0.0, 0.12277673, 0.0, 0.41839737, 0.09081799,...</td>
#       <td>Venture Capital</td>
#       <td>Seed Round</td>
#       <td>Seed Round</td>
#       <td>The  company raised GBP 1.81 million of seed f...</td>
#       <td>Developer  of an online insurance platform des...</td>
#       <td>The  company raised GBP 2.83 million of seed f...</td>
#       <td>2018-04-10</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>pirkx</td>
#       <td>14.00</td>
#       <td>12.0</td>
#       <td>employee  benefit, employee engagement, employ...</td>
#       <td>FinTech, SaaS</td>
#       <td>Other Commercial Services, Other Financial Ser...</td>
#       <td>Generating Revenue</td>
#       <td>Current Bussiness Status</td>
#       <td>Venture Capital-Backed</td>
#       <td>2.29</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1.61</td>
#       <td>1.61</td>
#       <td>1.61</td>
#       <td>1.00</td>
#       <td>None</td>
#       <td>0.000000</td>
#       <td>None</td>
#       <td>None</td>
#       <td>

# %% [markdown]
# ## 2. Generate Feature Embeddings

# %% [markdown]
# ### Time Series Features

# %%
ts_features = ['Deal Type', 'Deal Type 2', 'Deal Class', 'Deal Date']   
ts_df = clean_df[ts_features] 
ts_df
# Out:
#            Deal Type Deal Type 2       Deal Class   Deal Date
# 0     Later Stage VC    Series C  Venture Capital  2023-12-31
# 1     Later Stage VC    Series A  Venture Capital  2022-06-13
# 2         Seed Round  Seed Round  Venture Capital  2022-06-08
# 3     Early Stage VC    Series A  Venture Capital  2022-06-07
# 4     Later Stage VC    Series B  Venture Capital  2022-06-07
# ...              ...         ...              ...         ...
# 2542      Seed Round  Seed Round  Venture Capital  2022-04-21
# 2543  Early Stage VC          NA  Venture Capital  2021-01-01
# 2544  Early Stage VC          NA  Venture Capital  2018-03-29
# 2545  Early Stage VC          NA  Venture Capital  2018-11-26
# 2546  Later Stage VC          NA  Venture Capital  2021-01-01
#
# [2440 rows x 4 columns]

# %%
ts_df.set_index('Deal Date', inplace=True)
ts_df
# Out:
#                  Deal Type Deal Type 2       Deal Class
# Deal Date
# 2023-12-31  Later Stage VC    Series C  Venture Capital
# 2022-06-13  Later Stage VC    Series A  Venture Capital
# 2022-06-08      Seed Round  Seed Round  Venture Capital
# 2022-06-07  Early Stage VC    Series A  Venture Capital
# 2022-06-07  Later Stage VC    Series B  Venture Capital
# ...                    ...         ...              ...
# 2022-04-21      Seed Round  Seed Round  Venture Capital
# 2021-01-01  Early Stage VC          NA  Venture Capital
# 2018-03-29  Early Stage VC          NA  Venture Capital
# 2018-11-26  Early Stage VC          NA  Venture Capital
# 2021-01-01  Later Stage VC          NA  Venture Capital
#
# [2440 rows x 3 columns]

# %%
def onehot_encode_pd(df, col_name):
    dummies = pd.get_dummies(df[col_name], prefix=col_name)
    return pd.concat([df, dummies], axis=1).drop(columns=[col_name])

ts_df = onehot_encode_pd(ts_df, 'Deal Class')
ts_df = onehot_encode_pd(ts_df, 'Deal Type')
ts_df = onehot_encode_pd(ts_df, 'Deal Type 2')
ts_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Deal Class_Corporate</th>
#       <th>Deal Class_Hedge Fund</th>
#       <th>Deal Class_Individual</th>
#       <th>Deal Class_Other</th>
#       <th>Deal Class_Venture Capital</th>
#       <th>Deal Type_Accelerator/Incubator</th>
#       <th>Deal Type_Angel (individual)</th>
#       <th>Deal Type_Early Stage VC</th>
#       <th>Deal Type_Later Stage VC</th>
#       <th>Deal Type_Seed Round</th>
#       <th>Deal Type 2_Angel (individual)</th>
#       <th>Deal Type 2_NA</th>
#       <th>Deal Type 2_Seed Round</th>
#       <th>Deal Type 2_Series 1</th>
#       <th>Deal Type 2_Series 2</th>
#       <th>Deal Type 2_Series 3</th>
#       <th>Deal Type 2_Series A</th>
#       <th>Deal Type 2_Series A1</th>
#       <th>Deal Type 2_Series A2</th>
#       <th>Deal Type 2_Series A3</th>
#       <th>Deal Type 2_Series B</th>
#       <th>Deal Type 2_Series B1</th>
#       <th>Deal Type 2_Series B2</th>
#       <th>Deal Type 2_Series C</th>
#       <th>Deal Type 2_Series C1</th>
#       <th>Deal Type 2_Series C2</th>
#       <th>Deal Type 2_Series C3</th>
#       <th>Deal Type 2_Series D</th>
#       <th>Deal Type 2_Series E</th>
#       <th>Deal Type 2_Series F</th>
#       <th>Deal Type 2_Series G</th>
#       <th>Deal Type 2_Series H</th>
#     </tr>
#     <tr>
#       <th>Deal Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2023-12-31</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2022-06-13</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2022-08-06</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2022-07-06</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2022-07-06</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2021-01-01</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2021-01-01</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2021-01-01</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2021-01-01</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</

# %%
training_mean = ts_df.mean()
training_std = ts_df.std()
df_training_value = (ts_df - training_mean) / training_std
len(df_training_value)
# Out:
# 2440

# %%
TIME_STEPS = 2440

# Generate training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)
# Out:
# Training input shape:  (1, 2440, 32)

# %%
model = keras.Sequential(
    [
        layers.Input(shape=(x_train.shape[1], x_train.shape[2])),
        layers.Conv1D(
            filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1D(
            filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Conv1DTranspose(
            filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1DTranspose(
            filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 1220, 32)          7200
#
#  dropout_2 (Dropout)         (None, 1220, 32)          0
#
#  conv1d_3 (Conv1D)           (None, 610, 16)           3600
#
#  conv1d_transpose_3 (Conv1DT  (None, 1220, 16)         1808
#  ranspose)
#
#  dropout_3 (Dropout)         (None, 1220, 16)          0
#
#  conv1d_transpose_4 (Conv1DT  (None, 2440, 32)         3616
#  ranspose)
#
#  conv1d_transpose_5 (Conv1DT  (None, 2440, 1)          225
#  ranspose)
#
# =================================================================
# Total params: 16,449
# Trainable params: 16,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.pop()   # remove output layer (None, 2440, 1) to get the latent representation
latent_rep = model.predict(x_train)[0]

# %%
latent_vec = []
for i in range(ts_df.shape[0]):
    latent_vec.append(latent_rep[i])

latent_vec
clean_df['DateVector'] = latent_vec

# %%
timeseries_df = flat_df[["DealDate_t1", "DealDate_t2", "DealDate_t3"]]
timeseries_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DealDate_t1</th>
#       <th>DealDate_t2</th>
#       <th>DealDate_t3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[0.0, 0.0, 0.0, 0.09221074, 0.011161167, 0.002...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[0.0, 0.038540773, 0.09711099, 0.22219688, 0.0...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[0.13642836, 0.100364886, 0.0, 0.04559175, 0.0...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[0.0, 0.5521339, 0.0, 0.0, 0.089344405, 0.0, 0...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[0.0, 0.12277673, 0.0, 0.41839737, 0.09081799,...</td>
#       <td>[0.08290465, 0.0404652, 0.0, 0.05820749, 0.076...</td>
#       <td>[0.0, 0.24082406, 0.0, 0.0, 0.027381714, 0.044...</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>988</th>
#       <td>[0.102184944, 0.18636757, 0.0, 0.0, 0.02633296...</td>
#       <td>[0.1419558, 0.06810707, 0.0, 0.12760532, 0.064...</td>
#       <td>[0.0, 0.036394794, 0.20835912, 0.16356935, 0.0...</td>
#     </tr>
#     <tr>
#       <th>989</th>
#       <td>[0.09169653, 0.0, 0.042879775, 0.08549973, 0.1...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>990</th>
#       <td>[0.12692794, 0.16879615, 0.0, 0.0, 0.05778403,...</td>
#       <td>[0.0, 0.0, 0.23588568, 0.28649843, 0.001226592...</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>991</th>
#       <td>[0.28570512, 0.66700345, 0.0, 0.08349978, 0.00...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>992</th>
#       <td>[0.19127887, 0.12688063, 0.0, 0.0, 0.0, 0.2150...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# <p>993 rows × 3 columns</p>
# </div>

# %%
ts_embeddings = []
for idx, row in timeseries_df.iterrows():
    temp = []
    if type(row['DealDate_t1']) is not str:
        temp.append(row['DealDate_t1'])
    if type(row['DealDate_t2']) is not str:
        temp.append(row['DealDate_t2'])
    if type(row['DealDate_t3']) is not str:
        temp.append(row['DealDate_t3'])
    ts_embeddings.append(np.mean(temp, axis=0))

# %%
ts_embeddings = np.stack(ts_embeddings, axis=0)
ts_embeddings

# %% [markdown]
# ### 2.2 Generate Text Embeddings using DistilBERT

# %%
from transformers import BertTokenizer, TFBertModel, BertConfig, TFDistilBertModel, DistilBertTokenizer, DistilBertConfig

# %%
# Text preprocessing
def preprocess_sentence(line):
    line = line.replace("$", " dollars ")
    line = line.replace(" GBP ", " pounds ")
    line = re.sub(r"[,']+", "", line)
    line = re.sub(r"[^a-zA-Z0-9. ]+", " ", line)
    line = re.sub(r'[" "]+', " ", line)
    return line

# %%
text_features = ['Synopsis_t1', "Synopsis_t2", "Synopsis_t3", "Description", 'FinStatusNote', "Keywords", "Verticals", "Industries", 'BusinessStatus', 'CurrentBusinessStatus',
       'CurrentFinancingStatus', 'LeadInvestor']
for column in text_features:
    flat_df[column] = flat_df[column].map(preprocess_sentence)

# %%
dbert_tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased', do_basic_tokenize=True)
dbert_model = TFDistilBertModel.from_pretrained('distilbert-base-uncased')
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertModel: ['vocab_layer_norm', 'vocab_projector', 'activation_13', 'vocab_transform']
# - This IS expected if you are initializing TFDistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertModel were initialized from the model checkpoint at distilbert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.

# %%
def create_embeddings(column):
    emb = []
    sentences = flat_df[column]
    for sent in sentences:
        sent = dbert_tokenizer.basic_tokenizer.tokenize(sent)
        dbert_inps=dbert_tokenizer.encode_plus(sent, add_special_tokens = True,max_length = 250, pad_to_max_length = False, return_attention_mask = True,truncation=True)
        out=dbert_model(np.asarray(dbert_inps['input_ids']).reshape(1,-1),np.asarray(dbert_inps['attention_mask']).reshape(1,-1))
        emb.append(out[0][:,0,:].numpy())
    return emb

# %%
for column in text_features:
    flat_df[column] = create_embeddings(column)

# %%
text_df = flat_df[text_features].to_numpy()
text_df

# %%
text_embeddings = np.mean(text_df, axis = 1)
text_embeddings = [emb.flatten() for emb in text_embeddings]
text_embeddings = np.stack(text_embeddings, axis = 0)
text_embeddings

# %% [markdown]
# ### 2.3 Generate Numerical Features

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
num_features = ["EmployeeGrowth", "CurrentEmployees", "TotalRaised", "LastDealNo", 'PrevVC(Up/Down)', 'AvgDealSize', 'AvgEquity', 'PrevEquity',
                'AvgVCRound', 'NumFollowOnInvestors']

# %%
flat_df[num_features] = scaler.fit_transform(flat_df[num_features])

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

x_train = flat_df[num_features].to_numpy()
y_train = flat_df.isDeal.to_numpy().astype('int32')

model = Sequential()
model.add(Dense(64, input_dim=10, activation='relu'))
model.add(Dropout(0.5)) 
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5)) 
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',  
              metrics=['accuracy'])

model.fit(x_train, y_train,
          epochs=10,
          batch_size=128)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 1s 2ms/step - loss: 0.7149 - accuracy: 0.4089
# Epoch 2/10
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6467 - accuracy: 0.7966
# Epoch 3/10
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5943 - accuracy: 0.8640
# Epoch 4/10
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.8731
# Epoch 5/10
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4951 - accuracy: 0.8731
# Epoch 6/10
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4578 - accuracy: 0.8731
# Epoch 7/10
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4317 - accuracy: 0.8731
# Epoch 8/10
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4272 - accuracy: 0.8731
# Epoch 9/10
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4150 - accuracy: 0.8731
# Epoch 10/10
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4173 - accuracy: 0.8731

# %%
model2 = Sequential()
model2.add(Dense(64, input_dim = 10, weights=model.layers[0].get_weights()))
model2.add(Activation('tanh'))

# %%
num_embeddings = model2.predict(flat_df[num_features].to_numpy())

# %% [markdown]
# ### 2.4 Concatenate Latent Feature Vectors

# %%
predict_features = np.concatenate((ts_embeddings, text_embeddings, num_embeddings), axis = 1)

# %%
ts_embeddings.shape, num_embeddings.shape, text_embeddings.shape, predict_features.shape
# Out:
# ((993, 32), (993, 64), (993, 768), (993, 864))

# %%
target = flat_df.isDeal.to_numpy()

# %%
df_vectors = pd.DataFrame(predict_features)
df_vectors["Company"] = flat_df["Company"]
df_vectors["isDeal"] = flat_df["isDeal"]
df_vectors = df_vectors.sample(frac=1)
company = df_vectors["Company"]
df_vectors.drop("Company", axis = 1, inplace = True)

# %% [markdown]
# ## 3. MLP model

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score

# %%
df_pred_features = df_vectors.loc[:, df_vectors.columns != 'isDeal']

# %%
train_x = df_pred_features[0:744]
train_y = df_vectors["isDeal"][0:744]

test_x = df_pred_features[744:]
test_y = df_vectors["isDeal"][744:]

# %%
train_x.shape, test_y.shape, train_y.shape, test_x.shape
# Out:
# ((744, 864), (249,), (744,), (249, 864))

# %%
train_x = scaler.fit_transform(train_x)
test_x = scaler.fit_transform(test_x)

# %% [markdown]
# ### Model 1 : sklearn Perceptron (generic)

# %%
Classifier = Perceptron(random_state = 40)

# %%
Classifier.fit(train_x, train_y)
# Out:
# Perceptron(random_state=40)

# %%
pred = Classifier.predict(test_x)
pred

# %%
score = np.round(accuracy_score(test_y, pred), 4)
score
# Out:
# 0.8353

# %%
confusion_matrix(test_y, pred)

# %% [markdown]
# ## Model 2: MLP (as per paper)
# (trained with Relu activation; sigmoid applied to feature representation (prediction layer))

# %%
model = Sequential()
model.add(Dense(64, input_dim=864, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',   # alt: rmsprop
              metrics=['accuracy'])

model.fit(train_x, train_y,
          epochs=75,
          batch_size=128)
# Out:
# Epoch 1/75
# 6/6 [==============================] - 1s 3ms/step - loss: 0.4947 - accuracy: 0.7487
# Epoch 2/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3641 - accuracy: 0.8831
# Epoch 3/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3631 - accuracy: 0.8831
# Epoch 4/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3579 - accuracy: 0.8831
# Epoch 5/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3658 - accuracy: 0.8831
# Epoch 6/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3570 - accuracy: 0.8831
# Epoch 7/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.8831
# Epoch 8/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3584 - accuracy: 0.8831
# Epoch 9/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3525 - accuracy: 0.8831
# Epoch 10/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3544 - accuracy: 0.8831
# Epoch 11/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3670 - accuracy: 0.8831
# Epoch 12/75
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3542 - accuracy: 0.8831
# Epoch 13/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3516 - accuracy: 0.8831
# Epoch 14/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3509 - accuracy: 0.8831
# Epoch 15/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3584 - accuracy: 0.8831
# Epoch 16/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3463 - accuracy: 0.8831
# Epoch 17/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3452 - accuracy: 0.8831
# Epoch 18/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3549 - accuracy: 0.8831
# Epoch 19/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3491 - accuracy: 0.8831
# Epoch 20/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3551 - accuracy: 0.8831
# Epoch 21/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3439 - accuracy: 0.8831
# Epoch 22/75
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3485 - accuracy: 0.8831
# Epoch 23/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3493 - accuracy: 0.8831
# Epoch 24/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3451 - accuracy: 0.8831
# Epoch 25/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3612 - accuracy: 0.8831
# Epoch 26/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3449 - accuracy: 0.8831
# Epoch 27/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3435 - accuracy: 0.8831
# Epoch 28/75
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3427 - accuracy: 0.8831
# Epoch 29/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3432 - accuracy: 0.8831
# Epoch 30/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3504 - accuracy: 0.8831
# Epoch 31/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3489 - accuracy: 0.8831
# Epoch 32/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3445 - accuracy: 0.8831
# Epoch 33/75
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3400 - accuracy: 0.8831
# Epoch 34/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3472 - accuracy: 0.8831
# Epoch 35/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3389 - accuracy: 0.8831
# Epoch 36/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3408 - accuracy: 0.8831
# Epoch 37/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3397 - accuracy: 0.8831
# Epoch 38/75
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3474 - accuracy: 0.8831
# Epoch 39/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3434 - accuracy: 0.8831
# Epoch 40/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3446 - accuracy: 0.8831
# Epoch 41/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3426 - accuracy: 0.8831
# Epoch 42/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3341 - accuracy: 0.8831
# Epoch 43/75
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3438 - accuracy: 0.8831
# Epoch 44/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3402 - accuracy: 0.8831
# Epoch 45/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3311 - accuracy: 0.8831
# Epoch 46/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3546 - accuracy: 0.8831
# Epoch 47/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3323 - accuracy: 0.8831
# Epoch 48/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3355 - accuracy: 0.8831
# Epoch 49/75
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3358 - accuracy: 0.8831
# Epoch 50/75
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3390 - accuracy: 0.8831
# Epoch 51/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3367 - accuracy: 0.8831
# Epoch 52/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3309 - accuracy: 0.8831
# Epoch 53/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3390 - accuracy: 0.8831
# Epoch 54/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3377 - accuracy: 0.8831
# Epoch 55/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3447 - accuracy: 0.8844
# Epoch 56/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3325 - accuracy: 0.8831
# Epoch 57/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3301 - accuracy: 0.8831
# Epoch 58/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3321 - accuracy: 0.8831
# Epoch 59/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3446 - accuracy: 0.8831
# Epoch 60/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3283 - accuracy: 0.8831
# Epoch 61/75
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3347 - accuracy: 0.8831
# Epoch 62/75
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3310 - accuracy: 0.8844
# Epoch 63/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3295 - accuracy: 0.8844
# Epoch 64/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3401 - accuracy: 0.8831
# Epoch 65/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3276 - accuracy: 0.8831
# Epoch 66/75
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3291 - accuracy: 0.8844
# Epoch 67/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3253 - accuracy: 0.8844
# Epoch 68/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3356 - accuracy: 0.8831
# Epoch 69/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3209 - accuracy: 0.8844
# Epoch 70/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3389 - accuracy: 0.8831
# Epoch 71/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3335 - accuracy: 0.8844
# Epoch 72/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3257 - accuracy: 0.8831
# Epoch 73/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3309 - accuracy: 0.8844
# Epoch 74/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3203 - accuracy: 0.8831
# Epoch 75/75
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3254 - accuracy: 0.8831

# %%
pred_prob = model.predict(test_x)
pred_prob

# %%
# Find threshold corresponding to optimal accuracy-recall tradeoff 
for prob in [0.3, 0.25, 0.2, 0.15, 0.1]:
    keras_pred = [1 if val >= prob else 0 for val in pred_prob]
    tn, fp, fn, tp = confusion_matrix(test_y, keras_pred).ravel()
    #tn, fp, fn, tp
    print(tn, fp, fn, tp, round(tp/(tp+fn),4), (tp/(tp + 0.5*(fp+fn))))
# Out:
# 210 0 39 0 0.0 0.0
# 210 0 39 0 0.0 0.0
# 207 3 37 2 0.0513 0.09090909090909091
# 179 31 24 15 0.3846 0.35294117647058826
# 132 78 13 26 0.6667 0.36363636363636365

# %%
# Startup is eligible for funding if probability of success is greater than 0.3
keras_pred = [1 if val > 0.2 else 0 for val in pred_prob]
confusion_matrix(test_y, keras_pred)

# %%
list(company)[744:]
# Out:
# ['Yordex',
#  'Landbay',
#  'DeFinity (Financial Software)',
#  'MoneyExpert',
#  'HANetf',
#  'FinGo',
#  'Voscuris',
#  'Payfriendz',
#  'Connectd',
#  'Kyshi',
#  'Cashfac',
#  'Plum(Financial Software)',
#  'Donr',
#  'Pave (Financial Software)',
#  'Float (Edinburgh)',
#  'Identidot',
#  'Kwikpay',
#  'Bumper',
#  'Blockchain.com',
#  'Amero',
#  'Osu',
#  'Trakti',
#  'swIDch',
#  'Envelop Risk',
#  'Transactive',
#  'Arkera',
#  'Copper',
#  'CIRCA5000',
#  'DMA LINK',
#  'XPO (Financial Software)',
#  'Abaka',
#  'Shares',
#  'RepOptim',
#  'GoodBox (B2C Electronics)',
#  'Kibo Finance',
#  'DeepView',
#  'Argent',
#  'NovaFori',
#  'iov42',
#  'BCB Group',
#  'Bite Investments',
#  'Unizest',
#  'ProsperUs (Financial Software)',
#  'Alpima',
#  'BOXD',
#  'Koodoo (Financial Software)',
#  'Zilch',
#  'CrowdJustice',
#  'Tomato Pay',
#  'Weavr',
#  'Wagonex',
#  'Lunabets',
#  'Heyguevara.com',
#  'Rossum',
#  'Offgrid.finance',
#  'Apperio',
#  'Web3Games',
#  'Ophelos',
#  'Twig',
#  'Adsum (Business/Productivity Software)',
#  'Parfin',
#  'Iclima Earth',
#  'Apexx',
#  'Tulipshare',
#  'Uqudo',
#  'Timworks',
#  'Onfido',
#  'Sharegain',
#  'Funderbeam',
#  'SquareBook',
#  'IslamicFinanceGuru',
#  'CommEq',
#  'Alte',
#  'Sovryn',
#  'Zash (Financial Software)',
#  'Knoma',
#  'AccessPay',
#  'Loyalize (Financial Software)',
#  'PortF',
#  'Rooser',
#  'NALA',
#  'Card Industry Professionals',
#  'Cross Network Intelligence',
#  'Farewill',
#  'Nimbla',
#  'Dashly',
#  'Essentia Analytics',
#  'Busha',
#  'House of Insurtech',
#  'Sixty (Financial Software)',
#  'Meniga',
#  'Yayzy',
#  'TransferGo',
#  'Bloktopia',
#  'Ticker',
#  'Paid',
#  'Lending Works',
#  'Commuter Club',
#  'Goldex (Financial Software)',
#  'Lendable',
#  'Zenfinex',
#  'Yoello',
#  'Hunit',
#  'The Baobab Network',
#  'Fiskl',
#  'ENIAN',
#  '3S Money',
#  'Tappit',
#  '2Pay',
#  'Fiat Republic',
#  'Lanistar',
#  'Kolleno',
#  'Vertex (Financial Software)',
#  'SumoPay',
#  'Konsentus',
#  'AccountsIQ',
#  'SalaryFits',
#  'AxeTrading',
#  'Together Price',
#  'Fnality International',
#  'Akrod',
#  'Levro',
#  'City FALCON',
#  'Percent',
#  'Avione',
#  'MishiPay',
#  'Sendry',
#  'Applied Blockchain',
#  'PortIT',
#  'Proplend',
#  'StepEx',
#  'ThinkMarkets',
#  'GuardHog',
#  'Sikoia',
#  'Gretel (Information Services (B2C))',
#  'WonderBill',
#  'Ezbob',
#  'Fentury',
#  'Planixs',
#  'GraniteShares',
#  'Hop (Financial Software)',
#  'LayerTwo',
#  'Saurus (Financial Software)',
#  'IcoPremier',
#  'Multiply (Financial Software)',
#  'Rest Less',
#  'LandlordInvest',
#  'Reducer',
#  'ManageMy',
#  'Augur',
#  'Superjoi',
#  'Kalgera',
#  'Urban Jungle',
#  'Regvolution',
#  'PowerPool',
#  'Crossflow',
#  'Konsileo',
#  'Rezolve',
#  'Suade',
#  'SaltPay',
#  'Cushon',
#  'Divido',
#  'Form3',
#  'Scallop',
#  'Coinfirm',
#  'Tillit',
#  'IntelliBonds',
#  'TotemFi',
#  'Taptap Send',
#  'Odin (Financial Services)',
#  'Nexus Mutual',
#  'Finbourne',
#  'Bank of Telecom',
#  'Globe',
#  'Ffrees',
#  'Vertice',
#  'Fly Now Pay Later',
#  'Embargo',
#  'Pillar (Financial Software)',
#  'Rosecut',
#  'Boox',
#  'Phuture (Financial Software)',
#  'Derivitec',
#  'Bayfikr',
#  'Kession',
#  'World Mobile',
#  'Swoop (Financial Software)',
#  'Humn.ai',
#  'Credits',
#  'Plethori',
#  'Modulr (Financial Software)',
#  'Growth Street',
#  'Funding Xchange',
#  'Fundment',
#  'RightIndem',
#  'Funding Options',
#  'Habito',
#  'Plotify',
#  'Impact Rooms',
#  'Cognitive Credit',
#  'Neptune Networks (Financial Software)',
#  'Avantgarde Finance',
#  'VALK',
#  'Tide',
#  '365 Business Finance',
#  'Judo (Financial Software)',
#  'Purple Dot',
#  'ClearGlass',
#  'Cocoon (Financial Software)',
#  'Blossom Capital',
#  'Beyond [Financial Software]',
#  'trustshare',
#  'Income Analytics',
#  'Agam ( Consumer Finance)',
#  'Strabo',
#  'Capdesk',
#  'Quantexa',
#  'Crowdfunder (Newquay)',
#  'Fintern',
#  'Haruko',
#  'Wectory',
#  'Depoway',
#  'Qarma Technology',
#  'Pace Revenue',
#  'Wealthyhood',
#  'Darwin (Automotive Insurance)',
#  'Starling Bank',
#  'SteelEye',
#  'Billon',
#  'Levantor',
#  'Blockchain Technology Partners',
#  'CoInvestor',
#  'Invstr',
#  'Chaser',
#  'Vader Protocol',
#  'Senit',
#  'Botanical Holding',
#  'Seclea',
#  'Buenbit',
#  'GivePenny',
#  'Globacap',
#  'Adrix',
#  'RateSwitch',
#  'Upside (London)',
#  'Moneyhub Enterprise',
#  'Orka',
#  'pawaPay',
#  'Fregnan',
#  'Celo']

# %%
predictions = {"CompanyName": list(company)[744:], "PredictedProbability": pred_prob.tolist(), "isFunding":test_y.to_list()}
predictions_df = pd.DataFrame(predictions)

# %%
predictions_df = predictions_df.sort_values(by=['PredictedProbability'], ascending=False)
predictions_df.to_csv("Predictions.csv", header=True)
